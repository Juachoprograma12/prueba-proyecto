# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nobel = pd.read_csv('/content/sample_data/nobel (2).csv')
nobel.head()
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# ...

# %%
nobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 911 entries, 0 to 910
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  911 non-null    int64
#  1   category              911 non-null    object
#  2   prize                 911 non-null    object
#  3   motivation            823 non-null    object
#  4   prize_share           911 non-null    object
#  5   laureate_id           911 non-null    int64
#  6   laureate_type         911 non-null    object
#  7   full_name             911 non-null    object
#  8   birth_date            883 non-null    object
#  9   birth_city            883 non-null    object
#  10  birth_country         885 non-null    object
#  11  sex                   885 non-null    object
#  12  organization_name     665 non-null    object
#  13  organization_city     667 non-null    object
#  14  organization_country  667 non-null    object
# ...

# %% [markdown]
# # Conocer el conjunto de forma general
#
# Lo primero que vamos a hacer es reporndernos las siguientes preguntas
#
# - Cuántos premios tenemos registrados? Existen en este conjunto *911* premios
# - Cuántos premios han ganados hombres y mujeres? - Hombres tienen *836* premios y las mujeres solamente tienen *49*
# -Que países han ganado más premios? - *EEUU* Ocupa el prmer lugar como el país con más premios
# -Que categoria tiene más premios? - La categoría con más premios es medicina

# %%
display(len(nobel))

display(nobel['sex'].value_counts())


display(nobel['birth_country'].value_counts().head(10))


nobel['category'].value_counts().head(10)
# Out:
# 911
# sex
# Male      836
# Female     49
# Name: count, dtype: int64
# birth_country
# United States of America    259
# United Kingdom               85
# Germany                      61
# France                       51
# Sweden                       29
# Japan                        24
# Canada                       18
# Netherlands                  18
# Italy                        17
# Russia                       17
# Name: count, dtype: int64
# category
# Medicine      211
# Physics       204
# Chemistry     175
# Peace         130
# Literature    113
# Economics      78
# Name: count, dtype: int64

# %% [markdown]
# # Qué porcentaje de ganadores tiene EEUU por década?
#
# Conociendo que EEUU es el país que más ha ganado, conoceremos el porcentaje de victoria que han tednido por decada.

# %%
nobel['usa_born_winner'] = nobel['birth_country'] == "United States of America"
nobel.head()
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# ...

# %%
nobel['decade'] = (np.floor(nobel['year'] /10) *10).astype(int)
prop_usa_winners = nobel.groupby('decade', as_index=False)['usa_born_winner'].mean()

# %%
prop_usa_winners
# Out:
#     decade  usa_born_winner
# 0     1900         0.017544
# 1     1910         0.075000
# 2     1920         0.074074
# 3     1930         0.250000
# 4     1940         0.302326
# 5     1950         0.291667
# 6     1960         0.265823
# 7     1970         0.317308
# 8     1980         0.319588
# 9     1990         0.403846
# 10    2000         0.422764
# 11    2010         0.292683

# %%
plt.rcParams['figure.figsize'] = [11,7]

ax = sns.lineplot(
  x ='decade',
  y ='usa_born_winner',
  data= prop_usa_winners
)

from matplotlib.ticker import PercentFormatter

ax.yaxis.set_major_formatter('PercentFormatter')

# %% [markdown]
# Cuál es el porcentaje de victoria entre hombres y mujeres en las distintas categorias?

# %%
nobel['Female_winner'] = nobel['sex'] == 'Female'
prop_female_winners = nobel.groupby(['decade', 'category'], as_index=False)['Female_winner'].mean()

prop_female_winners
# Out:
#     decade    category  Female_winner
# 0     1900   Chemistry       0.000000
# 1     1900  Literature       0.100000
# 2     1900    Medicine       0.000000
# 3     1900       Peace       0.071429
# 4     1900     Physics       0.076923
# ..     ...         ...            ...
# 61    2010   Economics       0.000000
# 62    2010  Literature       0.285714
# 63    2010    Medicine       0.125000
# 64    2010       Peace       0.400000
# 65    2010     Physics       0.000000
#
# [66 rows x 3 columns]

# %%
ax = sns.lineplot(
    x = 'decade',
    y = 'Female_winner',
    data=prop_female_winners,
    hue='category'
)

ax.yaxis.set_major_formatter(PercentFormatter())

# %% [markdown]
# - Las categorias en donde menos ha ganado son las siguientes:
#
# - Física
# - Química
# - Economía
# - Lascategorias en donde las mujeres han ganado más son las siguientes:
#
# - Literatura
# - Medicina
# - Paz

# %% [markdown]
# Edad hay más ganadores

# %%
nobel['birth_date'] = pd.to_datetime(nobel['birth_date'])

nobel['age'] = nobel['year'] - nobel['birth_date'].dt.year

nobel.head()
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name birth_date         birth_city  \
# ...

# %%
sns.lmplot(
    x = 'year',
    y = 'age',
    data = nobel,
    lowess = True,
    aspect = 2,
    line_kws= {'color': 'black'},
    row = 'category'
)

# %% [markdown]
# # Rando de edad de los ganadores en las diferentes categorias

# %% [markdown]
# Las categorías en donde la edad necesaria para gnar un premio nobel ha ido en aumento son las siguientes:
#
# -Física
# -Química
# -Medicina
#
# Y las categorías en donde el rango de edad se manteineo o ha bajado son:
#
# -Paz
# -Economía
# -Literatura

# %% [markdown]
# # Quién es la persona más vieja en ganar el premio nobel y quien es la más joven

# %%
display(nobel.nlargest(1, 'age'))

nobel.nsmallest(1, 'age')
# Out:
#      year   category                                              prize  \
# 793  2007  Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             motivation prize_share  \
# 793  "for having laid the foundations of mechanism ...         1/3
#
#      laureate_id laureate_type       full_name birth_date birth_city  \
# 793          820    Individual  Leonid Hurwicz 1917-08-21     Moscow
#
#     birth_country   sex        organization_name organization_city  \
# 793        Russia  Male  University of Minnesota   Minneapolis, MN
#
#          organization_country  death_date       death_city  \
# 793  United States of America  2008-06-24  Minneapolis, MN
#
#                 death_country  birt_date   age
# 793  United States of America 1917-08-21  90.0
#      year category                       prize  \
# 885  2014    Peace  The Nobel Peace Prize 2014
#
#                                             motivation prize_share  \
# ...
